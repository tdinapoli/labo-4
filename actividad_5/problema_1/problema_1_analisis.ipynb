# %% [markdown]
# # Análsis de la actividad 1: Determinación de la función de transferencia
# ![image.png](attachment:image.png)

# %%
import numpy as np
from matplotlib import pyplot as plt

R_0 = np.loadtxt('datos/actividad_1/R_f8_s12.txt') #Radio con el filtro de orden 0, tiempo de integracion 8 y sensibilidad 12
R_3 = np.loadtxt('datos/actividad_1/R_f8_s12_o3.txt') #Radio con el filtro de orden 3, tiempo de integracion 8 y sensibilidad 12

T_0 = np.loadtxt('datos/actividad_1/tita_f8_s12.txt') #Fase con el filtro de orden 0, tiempo de integracion 8 y sensibilidad 12
T_3 = np.loadtxt('datos/actividad_1/tita_f8_s12_o3.txt') #Fase con el filtro de orden 3, tiempo de integracion 8 y sensibilidad 12

#Ploteo y comparacion para determinar con que orden del filtro trabajar
plt.plot(R_0, 'r.')
plt.plot(R_3, 'b.')

#funcion de transferencia  = valor medio de los R / Vi  siendo vi = 0.1 V . Hay que multiplicarlo por 2

transferencia = np.mean(R_3)*2/0.1
er_transferencia = np.std(R_3)*4/0.1

# %% [markdown]
# #  Cambios 25/05

# %%
# %matplotlib widget

R = np.loadtxt('25-05/actividad_1/datos/R_p1_fc8_s12_o3.txt')
T = np.loadtxt('25-05/actividad_1/datos/T_p1_fc8_s12_o3.txt')

plt.figure(facecolor='white')
plt.plot(R,'.b')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
