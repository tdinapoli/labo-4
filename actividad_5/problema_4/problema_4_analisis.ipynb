# %% [markdown]
# # Análisis actividad 4: Linealidad de medición en función de voltajes
# ![image.png](attachment:image.png)
#
# #### Se eligió un frecuencia de 10k Hz ya que por esas frecuencias se ve que la respuesta es como queremos. Se recorrieron todos los voltages posibles, se untilizó un tiempo de integración  = 8 y el filtro de orden 3. La sensibilidad se seteo en 17 ya que no saturaba ni sobre-saturaba en ninguno de los puntos tomados

# %%
import numpy as np
from matplotlib import pyplot as plt

R = np.loadtxt('datos_viejos/actividad_4/Rs_p4_fc8_s17_o3_fm10000.0_vmax4.95.txt')
T = np.loadtxt('datos_viejos/actividad_4/Ts_p4_fc8_s17_o3_fm10000.0_vmax4.95.txt')

amplitudes = np.arange(0.05, 4.95, 0.05)

plt.figure()
plt.plot(amplitudes, R, '.') #Se está graficando el voltaje de salida no la funcion de transferencia.
plt.xlabel('Amplitud [V]')
plt.ylabel('Medición del circuito en [V]') #por ahora falta multiplicar por 2
plt.grid()

plt.figure(facecolor='white')
plt.plot(amplitudes, T, '.-')
plt.ylabel('fase $\phi$ [grad]')
plt.xlabel('Amplitud [V]')
plt.grid()

# %% [markdown]
# # Cambios 25/05

# %%
# %matplotlib widget

R_m        = np.loadtxt('datos/Rmean_p4_fc8_s17_o3.txt')
R_m_fino   = np.loadtxt('datos/Rmean_fino_p4_fc8_s17_o3.txt')
R_m_fino_2 = np.loadtxt('datos/Rmean_fino2_p4_fc8_s17_o3.txt')

R_std        = np.loadtxt('datos/Rstd_p4_fc8_s17_o3.txt')
R_std_fino   = np.loadtxt('datos/Rstd_fino_p4_fc8_s17_o3.txt')
R_std_fino_2 = np.loadtxt('datos/Rstd_fino2_p4_fc8_s17_o3.txt')

vm1 = 4.95
vm2 = 1
vm3 = 0.2
a1 = np.arange(0.05, vm1, 0.05)
a2 = np.arange(0.05, vm2, 0.01)
a3 = np.arange(0.005, vm3, 0.002)

plt.figure(facecolor='white')
plt.plot(a1, R_m, 'b.', label = 'Barrido entre 0.05 y 4.95')
plt.plot(a2, R_m_fino, 'g.', label = 'Barrido entre 0.05 y 1')
plt.plot(a3, R_m_fino_2, 'r.', label = 'Barrido entre 0.005 y 0.002')
plt.ylabel('Salida [V]')
plt.xlabel('Entrada [V]')
plt.legend()

plt.figure()
plt.title('Ruido/Señal')
plt.plot(a1, R_std/R_m, 'b.', label = 'Barrido entre 0.05 y 4.95')
plt.plot(a2, R_std_fino/R_m_fino, 'g.', label = 'Barrido entre 0.05 y 1')
plt.plot(a3, R_std_fino_2/R_m_fino_2, 'r.', label = 'Barrido entre  0.005 y 0.002')
plt.xlabel('Entrada [V]')
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Mediciones 28/05 Agregamos tsleep más grande y medicones con y sin el filtro Notch

# %%
R_m = np.loadtxt('datos_2805/Rmean_p4_fc8_s17_o3_tsleep15.txt')
R_std = np.loadtxt('datos_2805/Rstd_p4_fc8_s17_o3_tsleep15.txt')
R_fino_m = np.loadtxt('datos_2805/Rmean_fino_p4_fc8_s17_o3_tsleep15.txt')
R_fino_std = np.loadtxt('datos_2805/Rstd_fino_p4_fc8_s17_o3_tsleep15.txt')

R_m_sN = np.loadtxt('datos_2805/Rmean_p4_fc8_s17_o3_tsleep15_sN.txt')
R_std_sN = np.loadtxt('datos_2805/Rstd_p4_fc8_s17_o3_tsleep15_sN.txt')
R_fino_m_sN = np.loadtxt('datos_2805/Rmean_fino_p4_fc8_s17_o3_tsleep15_sN.txt')
R_fino_std_sN = np.loadtxt('datos_2805/Rstd_fino_p4_fc8_s17_o3_tsleep15_sN.txt')

T_m_ = np.loadtxt('datos_2805/Tmean_p4_fc8_s17_o3_tsleep15.txt')
T_m_fino_ = np.loadtxt('datos_2805/Tmean_fino_p4_fc8_s17_o3_tsleep15.txt')

T_m_sN_ = np.loadtxt('datos_2805/Tmean_p4_fc8_s17_o3_tsleep15_sN.txt')
T_m_fino_sN_ = np.loadtxt('datos_2805/Tmean_fino_p4_fc8_s17_o3_tsleep15_sN.txt')

T_m = []
T_m_fino = []
T_m_sN = []
T_m_fino_sN =[]
for i in range(len(T_m_)):
    if (i % 2) == 0:
        T_m.append(T_m_[i])
        T_m_fino.append(T_m_fino_[i])
        T_m_sN.append(T_m_sN_[i])
        T_m_fino_sN.append(T_m_fino_sN_[i])
# for i in range(len(T_m_)):
#     if (i % 2) == 0:
#         T_m.append(T_m_[i])
#         T_m_fino.append(T_m_fino_[i])
#         T_m.append(T_m_sN_[i])
#         T_m_fino_sN.append(T_m_fino_sN_[i])

amp = np.arange(0.05, 4.95, 0.05)
amp_fino = np.arange(0.005, 0.2, 0.002)

plt.figure(facecolor = 'white')
plt.title('Linealidad del circuito')
plt.plot(amp, R_m, '.')
plt.plot(amp_fino, R_fino_m,'.')
plt.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Comparacion de Señal/Ruido y las fases con y sin el filtro Notch

# %%
fig, (ax1,ax2) = plt.subplots(1, 2, figsize = (9,4),facecolor = 'white')
ax1.set_title('Filtro Notch encendido')
ax1.semilogy(amp, R_m/R_std, '.')
ax1.semilogy(amp_fino, R_fino_m/R_fino_std,  '.')
ax1.grid()

ax2.set_title('Filtro Notch apagado')
ax2.semilogy(amp, R_m_sN/R_std_sN, '.')
ax2.semilogy(amp_fino, R_fino_m_sN/R_fino_std_sN,  '.')
ax2.grid()

fig, (ax1,ax2) = plt.subplots(1, 2, figsize = (9,4),facecolor = 'white')
ax1.set_title('Fase Notch encendido')
ax1.plot(amp,T_m, '.')

ax2.set_title('Fase Notch apagado')
ax2.plot(amp, T_m_sN,'.')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from scipy.optimize import curve_fit
def lineal(x, m, b):
    y = m*x + b
    return y

popt, pcov = curve_fit(lineal, amp, R_m)
perr = np.sqrt(np.diag(pcov))

m, b = popt[0], popt[1]
x = np.linspace(0,4.95,98)
y = m*x + b


plt.figure(facecolor = 'white')
plt.plot(x,y)
plt.title('Linealidad del circuito')
plt.plot(amp, R_m, '.')
plt.plot(amp_fino, R_fino_m,'.')
plt.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from scipy.stats import chi2

def chisq(ydata, ymodelo,sd):
    chisq = sum(((ydata-ymodelo)/sd)**2)
    return chisq
    
def rval( ydata, chi, gl):  #reduce chi square   gl = numero de parametros de la funcion es bueno q este cerca de 1
    k=len(ydata)-1-gl
    rval=chi/k   
    return rval, k

def pvalor(chi, k):         #integral de ña distribucion de chisq es bueno q este cerca de 0
    p  = 1- chi2.cdf(chi, k)
    return p

chi = chisq(R_m, y, R_std)
r = rval(R_m,chi, 1)
p = pvalor(chi, r[1])

r[0], p
# Out:
# (10318.27122741876, 0.0)

# %%
from scipy.stats import linregress
linregress(amp, R_m)
# Out:
# LinregressResult(slope=9.920255265586647e-05, intercept=-2.8881121228666994e-08, rvalue=0.9999999562514074, pvalue=0.0, stderr=2.9949135201091104e-09)
