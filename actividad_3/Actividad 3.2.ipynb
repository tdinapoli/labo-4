# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib nbagg

E_laton = 110e9 #Pa
E_acero = 210e9 #Pa
ro_acero = 7850 #kg/m³
ro_laton = 8730 #kg/m³
L = 0.3

lado_rec = 0.04
alto_rec = 0.00
I_rec = lado_rec * alto_rec**3 / 12
A = lado_rec * alto_rec

radio_vara = 0.0026
seccion_vara = np.pi* radio_vara**2
I_vara = np.pi * radio_vara**4 / 4


b_ls = [1.875, 4.694, 7.854]

ws_laton = []
ws_acero = []

for bl in b_ls:
    num_lat = bl**2 * np.sqrt(E_laton * I_vara)
    den_lat = L**2 * np.sqrt(ro_laton * seccion_vara)
    num_ac = bl**2 * np.sqrt(E_acero * I_vara)
    den_ac = L**2  * np.sqrt(ro_acero * ro_acero * seccion_vara)
    ws_laton.append(num_lat/den_lat)
    ws_acero.append(num_ac/den_ac)

print(ws_laton, ws_acero)
# Out:
# [180.25719460053426, 1129.7340905839892, 3162.8009273478965] [2.9644448663627547, 18.579199751823808, 52.014284329575624]
