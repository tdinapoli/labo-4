# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para q la difración de Fraunhoffer ocurra se tiene q D > $a^2 / \lambda$. Considerando que la rendija se encuentra al fondo de la barra, pido que a, el tamaño de la rendija, sea la mayor distancia entre la barra y la horizontal, es decir el parametro calculado en el ejercicio anterior, obteniendo asi, a = 0.00068145m. Consideramos un laser rojo de Helio-Neon de longitud de onda $6.328 x 10^{-7} m$

# %%
a = 0.00068145
l = 6.328e-7

cuenta = (a**2) /l
print(cuenta)
# Out:
# 0.7338402378318585

# %% [markdown]
# D > 0.734m
